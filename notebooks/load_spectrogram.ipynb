# %%
from audiosep.data import wav_to_mag_phase

mag_mix, phase_mix = wav_to_mag_phase("../data/train_small/0001/mix_snr_0.wav")
mag_voice, _ = wav_to_mag_phase("../data/train_small/0001/voice.wav")
mag_noise, _ = wav_to_mag_phase("../data/train_small/0001/noise.wav")

print(mag_mix.shape)   # (F, T)

# Plot the magnitude spectrogram
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.imshow(mag_voice, aspect='auto', origin='lower')
plt.colorbar(format='%+2.0f dB')
plt.title('Magnitude Spectrogram of Voice Audio')
plt.xlabel('Time Frames')
plt.ylabel('Frequency Bins')
plt.tight_layout()
plt.show()
# Out:
# torch.Size([513, 107])
